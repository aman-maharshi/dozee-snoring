# %% [markdown]
# Attempt 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('test1.csv')

# %%
data.head()
# Out:
#    46
# 0  45
# 1  45
# 2  45
# 3  45
# 4  48

# %%
data.plot()

# %%
#first snoring cycle  
data[500:1200].plot(figsize=(13,4), kind='line')

# %%
# non-snoring vs snoring instance
data[550:650].plot()

# %%
data.head()
# Out:
#    46
# 0  45
# 1  45
# 2  45
# 3  45
# 4  48

# %%
data.columns = ['vibrations']

# %%
data.head()
# Out:
#    vibrations
# 0          45
# 1          45
# 2          45
# 3          45
# 4          48

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data1 = data[0:1200]; data1.plot()

# %%
data[0:3000].plot()

# %%
# non-snoring data
data1 = data[500:600]; data1.plot()

# %%
# snoring data
data2 = data[600:700]; data2.plot()

# %%
data[500:700].plot()

# %%
data1['vibrations'].head()
# Out:
# 500    46
# 501    43
# 502    41
# 503    38
# 504    36
# Name: vibrations, dtype: int64

# %%
diff1 = []
for x in range(500, 598):
    diff1.append(data1['vibrations'][x+1] - data1['vibrations'][x])

# %%
diff2 = []
for x in range(600, 698):
    diff2.append(data2['vibrations'][x+1] - data2['vibrations'][x])

# %%
count = 0
for x in range(len(diff)-1):
    if diff[x+1] > diff[x]:
        count += 1

# %%
# max and min differnece for non snoring part
print max(diff1); print min(diff1)
# Out:
# 3
# -3

# %%
# max and min differnece for snoring part
print max(diff2); print min(diff2)
# Out:
# 6
# -7

# %%
diff = []
for x in range(0, 3000):
    diff.append(data['vibrations'][x+1] - data['vibrations'][x])

# %%
# finding the index of the point at which first snoring starts
li = []
for x in range(len(diff)-1):
    if diff[x] > 3:
        li.append(x)
        break   
for x in range(x+500, len(diff)-1):
    if diff[x] > 3:
        li.append(x)
        break
for x in range(x+500, len(diff)-1):
    if diff[x] > 3:
        li.append(x)
        break

print li
# Out:
# [618, 1698, 2775]

# %%
plt.figure(figsize=(20, 5))
plt.plot(data[0:3000])
plt.plot(data[618: 618+500],color='red')
plt.plot(data[1698: 1698+500],color='red')
plt.plot(data[2775: 2775+500],color='red')
